# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from A3C import A3C
from utils import discount
import os
from collections import defaultdict
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
load = True
device = 0
np.random.seed(12345)
torch.random.manual_seed(12345)

# %% [markdown]
# ## Maybe add in pseudo-random left/right later?

# %%
class lever():
    def __init__(self, FR_limit, PR_reward):
        super().__init__()
        self.mode = "PR"
        self.limits = {"PR":2, "FR":FR_limit}
        self.rewards = {"PR":PR_reward, "FR":1}
        self.progress = 0
    def pull(self, choice):
        modes = ["PR", "FR"]
        if modes[choice] == self.mode:
            self.progress += 1
        else:
            self.progress = 1
            self.mode = modes[choice]
        if self.progress > self.limits[modes[choice]]:
            print("error: progress shouldn't be greater than limit")
        if self.progress ==  self.limits[modes[choice]]:
            if modes[choice] == "PR":
                self.limits["PR"] += 1
            self.progress = 0
            return self.rewards[modes[choice]]
        return 0

agent = A3C().cuda(device)
optimizer = torch.optim.RMSprop(agent.parameters(), 0.0007)

# %%
# actions = [a0, a1, a2, ...., aT]
# value_preds = [V0, V1, V2, ...., VT]
# rewards = [r0, r1, r2, ..... , rT]
# value_target = []
def run_block(block_num, train = True, bv = 0.05, be = 0.05, discount_f = 0.75):
    num_presses = 2000 # perhaps this number needs to be changed
    FR_limit = [6, 12][np.random.choice(2)]
    PR_reward = [2, 5][np.random.choice(2)]
    experiment = lever(FR_limit, PR_reward)
    action = -1
    reward = 0.25 # this is an arbitrary number for the initial input
    lstm_state = None
    value_preds = []
    rewards = []
    actions = []
    policies = []
    for press_num in range(num_presses):
        action_probs, value_pred, lstm_state = agent(action, reward, lstm_state)
        action = np.random.choice([0, 1], p = action_probs.detach().cpu().numpy().flatten())
        reward = experiment.pull(action)
        policies.append(action_probs)
        value_preds.append(value_pred)
        actions.append(action)
        rewards.append(reward)
    value_targets = torch.Tensor(discount(rewards, discount_f)).cuda(device)
    value_preds = torch.Tensor(value_preds).cuda(device)
    policies = torch.cat(policies, dim = 0)
    actions = torch.Tensor(actions).long()
    advantage = (value_targets - value_preds).detach()
    if train:
        value_loss = torch.nn.MSELoss()(value_preds, value_targets)
        policy_loss = -torch.mean(torch.log(policies[torch.arange(policies.shape[0]), actions])*advantage)
        entropy_loss = torch.mean(torch.log(policies)*policies)*(20-block_num/1000)
        loss = policy_loss + value_loss*bv + entropy_loss*be
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
    
    # collect data
    actions = actions.numpy()
    rewards = np.array(rewards)
    print('session block:', block_num, 'reward:', sum(rewards)/len(rewards))
    return actions, rewards, FR_limit, PR_reward

# %%
if load and os.path.exists('models/PRvsFR.pth'):
    agent.load_state_dict(torch.load('models/PRvsFR.pth'))
else:
    for block_num in range(18000):
        run_block(block_num)
    torch.save(agent.state_dict(), "models/PRvsFR.pth")

# %%
d = defaultdict(list)
for block_num in range(500):
    actions, rewards, FR_limit, PR_reward = run_block(block_num, train = False)
    d[(FR_limit, PR_reward)].append((actions, rewards))
# Out:
# trial block: 0 reward: 0.19
# trial block: 1 reward: 0.31333333333333335
# trial block: 2 reward: 0.19333333333333333
# trial block: 3 reward: 0.29333333333333333
# trial block: 4 reward: 0.12666666666666668
# trial block: 5 reward: 0.29
# trial block: 6 reward: 0.29333333333333333
# trial block: 7 reward: 0.12
# trial block: 8 reward: 0.29
# trial block: 9 reward: 0.3233333333333333
# trial block: 10 reward: 0.12333333333333334
# trial block: 11 reward: 0.19333333333333333
# trial block: 12 reward: 0.31333333333333335
# trial block: 13 reward: 0.32
# trial block: 14 reward: 0.19
# trial block: 15 reward: 0.30333333333333334
# trial block: 16 reward: 0.12
# trial block: 17 reward: 0.2833333333333333
# trial block: 18 reward: 0.19333333333333333
# trial block: 19 reward: 0.29
# trial block: 20 reward: 0.28
# trial block: 21 reward: 0.2966666666666667
# trial block: 22 reward: 0.32
# trial block: 23 reward: 0.13
# trial block: 24 reward: 0.11666666666666667
# trial block: 25 reward: 0.11666666666666667
# trial block: 26 reward: 0.27666666666666667
# trial block: 27 reward: 0.11333333333333333
# trial block: 28 reward: 0.2966666666666667
# trial block: 29 reward: 0.27666666666666667
# trial block: 30 reward: 0.29333333333333333
# trial block: 31 reward: 0.18333333333333332
# trial block: 32 reward: 0.3
# trial block: 33 reward: 0.19
# trial block: 34 reward: 0.27666666666666667
# trial block: 35 reward: 0.11666666666666667
# trial block: 36 reward: 0.32
# trial block: 37 reward: 0.31333333333333335
# trial block: 38 reward: 0.12333333333333334
# trial block: 39 reward: 0.31666666666666665
# trial block: 40 reward: 0.3233333333333333
# trial block: 41 reward: 0.11666666666666667
# trial block: 42 reward: 0.27666666666666667
# trial block: 43 reward: 0.31333333333333335
# trial block: 44 reward: 0.11666666666666667
# trial block: 45 reward: 0.32
# trial block: 46 reward: 0.27
# trial block: 47 reward: 0.11333333333333333
# trial block: 48 reward: 0.12
# trial block: 49 reward: 0.31333333333333335
# trial block: 50 reward: 0.31333333333333335
# trial block: 51 reward: 0.12333333333333334
# trial block: 52 reward: 0.12333333333333334
# trial block: 53 reward: 0.12333333333333334
# trial block: 54 reward: 0.30666666666666664
# trial block: 55 reward: 0.31
# trial block: 56 reward: 0.3233333333333333
# trial block: 57 reward: 0.19
# trial block: 58 reward: 0.27666666666666667
# trial block: 59 reward: 0.19333333333333333
# trial block: 60 reward: 0.29333333333333333
# trial block: 61 reward: 0.18666666666666668
# trial block: 62 reward: 0.29333333333333333
# trial block: 63 reward: 0.19
# trial block: 64 reward: 0.32
# trial block: 65 reward: 0.3233333333333333
# trial block: 66 reward: 0.32
# trial block: 67 reward: 0.2633333333333333
# trial block: 68 reward: 0.19333333333333333
# trial block: 69 reward: 0.3233333333333333
# trial block: 70 reward: 0.11666666666666667
# trial block: 71 reward: 0.19
# trial block: 72 reward: 0.12
# trial block: 73 reward: 0.31333333333333335
# trial block: 74 reward: 0.27666666666666667
# trial block: 75 reward: 0.18666666666666668
# trial block: 76 reward: 0.12333333333333334
# trial block: 77 reward: 0.3233333333333333
# trial block: 78 reward: 0.11666666666666667
# trial block: 79 reward: 0.13
# trial block: 80 reward: 0.19
# trial block: 81 reward: 0.33
# trial block: 82 reward: 0.32
# trial block: 83 reward: 0.31
# trial block: 84 reward: 0.28
# trial block: 85 reward: 0.30666666666666664
# trial block: 86 reward: 0.3233333333333333
# trial block: 87 reward: 0.19
# trial block: 88 reward: 0.19
# trial block: 89 reward: 0.30333333333333334
# trial block: 90 reward: 0.32
# trial block: 91 reward: 0.18666666666666668
# trial block: 92 reward: 0.18666666666666668
# trial block: 93 reward: 0.19
# trial block: 94 reward: 0.11333333333333333
# trial block: 95 reward: 0.16333333333333333
# trial block: 96 reward: 0.2833333333333333
# trial block: 97 reward: 0.13
# trial block: 98 reward: 0.11333333333333333
# trial block: 99 reward: 0.31666666666666665
# trial block: 100 reward: 0.3233333333333333
# trial block: 101 reward: 0.31333333333333335
# trial block: 102 reward: 0.3233333333333333
# trial block: 103 reward: 0.12666666666666668
# trial block: 104 reward: 0.19333333333333333
# trial block: 105 reward: 0.29
# trial block: 106 reward: 0.19333333333333333
# trial block: 107 reward: 0.11333333333333333
# trial block: 108 reward: 0.32
# trial block: 109 reward: 0.33
# trial block: 110 reward: 0.2966666666666667
# trial block: 111 reward: 0.19333333333333333
# trial block: 112 reward: 0.11333333333333333
# trial block: 113 reward: 0.31666666666666665
# trial block: 114 reward: 0.32
# trial block: 115 reward: 0.19
# trial block: 116 reward: 0.11666666666666667
# trial block: 117 reward: 0.19333333333333333
# trial block: 118 reward: 0.19333333333333333
# trial block: 119 reward: 0.12666666666666668
# trial block: 120 reward: 0.12666666666666668
# trial block: 121 reward: 0.18666666666666668
# trial block: 122 reward: 0.19333333333333333
# trial block: 123 reward: 0.32
# trial block: 124 reward: 0.33
# trial block: 125 reward: 0.32
# trial block: 126 reward: 0.3233333333333333
# trial block: 127 reward: 0.29
# trial block: 128 reward: 0.12
# trial block: 129 reward: 0.3233333333333333
# trial block: 130 reward: 0.31333333333333335
# trial block: 131 reward: 0.31666666666666665
# trial block: 132 reward: 0.31
# trial block: 133 reward: 0.11333333333333333
# trial block: 134 reward: 0.11666666666666667
# trial block: 135 reward: 0.29
# trial block: 136 reward: 0.12666666666666668
# trial block: 137 reward: 0.27666666666666667
# trial block: 138 reward: 0.32
# trial block: 139 reward: 0.30333333333333334
# trial block: 140 reward: 0.3333333333333333
# trial block: 141 reward: 0.19333333333333333
# trial block: 142 reward: 0.19333333333333333
# trial block: 143 reward: 0.11666666666666667
# trial block: 144 reward: 0.19
# trial block: 145 reward: 0.2733333333333333
# trial block: 146 reward: 0.12
# trial block: 147 reward: 0.31333333333333335
# trial block: 148 reward: 0.19
# trial block: 149 reward: 0.30666666666666664
# trial block: 150 reward: 0.31
# trial block: 151 reward: 0.29333333333333333
# trial block: 152 reward: 0.12333333333333334
# trial block: 153 reward: 0.12333333333333334
# trial block: 154 reward: 0.29
# trial block: 155 reward: 0.32
# trial block: 156 reward: 0.12333333333333334
# trial block: 157 reward: 0.33
# trial block: 158 reward: 0.2866666666666667
# trial block: 159 reward: 0.33
# trial block: 160 reward: 0.31
# trial block: 161 reward: 0.33
# trial block: 162 reward: 0.19
# trial block: 163 reward: 0.19
# trial block: 164 reward: 0.27666666666666667
# trial block: 165 reward: 0.2866666666666667
# trial block: 166 reward: 0.32666666666666666
# trial block: 167 reward: 0.31333333333333335
# trial block: 168 reward: 0.11666666666666667
# trial block: 169 reward: 0.32
# trial block: 170 reward: 0.30666666666666664
# trial block: 171 reward: 0.32
# trial block: 172 reward: 0.31
# trial block: 173 reward: 0.11666666666666667
# trial block: 174 reward: 0.19
# trial block: 175 reward: 0.19
# trial block: 176 reward: 0.12666666666666668
# trial block: 177 reward: 0.31666666666666665
# trial block: 178 reward: 0.28
# trial block: 179 reward: 0.2866666666666667
# trial block: 180 reward: 0.28
# trial block: 181 reward: 0.12
# trial block: 182 reward: 0.19
# trial block: 183 reward: 0.12
# trial block: 184 reward: 0.29333333333333333
# trial block: 185 reward: 0.19333333333333333
# trial block: 186 reward: 0.19333333333333333
# trial block: 187 reward: 0.19333333333333333
# trial block: 188 reward: 0.12
# trial block: 189 reward: 0.27666666666666667
# trial block: 190 reward: 0.11333333333333333
# trial block: 191 reward: 0.32
# trial block: 192 reward: 0.19333333333333333
# trial block: 193 reward: 0.3233333333333333
# trial block: 194 reward: 0.3233333333333333
# trial block: 195 reward: 0.19333333333333333
# trial block: 196 reward: 0.3233333333333333
# trial block: 197 reward: 0.30666666666666664
# trial block: 198 reward: 0.12333333333333334
# trial block: 199 reward: 0.11333333333333333
# trial block: 200 reward: 0.12333333333333334
# trial block: 201 reward: 0.31666666666666665
# trial block: 202 reward: 0.3233333333333333
# trial block: 203 reward: 0.19
# trial block: 204 reward: 0.32
# trial block: 205 reward: 0.12
# trial block: 206 reward: 0.29
# trial block: 207 reward: 0.12
# trial block: 208 reward: 0.19666666666666666
# trial block: 209 reward: 0.2733333333333333
# trial block: 210 reward: 0.18666666666666668
# trial block: 211 reward: 0.31666666666666665
# trial block: 212 reward: 0.12
# trial block: 213 reward: 0.31333333333333335
# trial block: 214 reward: 0.19
# trial block: 215 reward: 0.19333333333333333
# trial block: 216 reward: 0.19
# trial block: 217 reward: 0.19
# trial block: 218 reward: 0.28
# trial block: 219 reward: 0.11333333333333333
# trial block: 220 reward: 0.30666666666666664
# trial block: 221 reward: 0.31666666666666665
# trial block: 222 reward: 0.32
# trial block: 223 reward: 0.12333333333333334
# trial block: 224 reward: 0.28
# trial block: 225 reward: 0.32
# trial block: 226 reward: 0.3233333333333333
# trial block: 227 reward: 0.12333333333333334
# trial block: 228 reward: 0.3
# trial block: 229 reward: 0.18666666666666668
# trial block: 230 reward: 0.3233333333333333
# trial block: 231 reward: 0.13
# trial block: 232 reward: 0.19333333333333333
# trial block: 233 reward: 0.29
# trial block: 234 reward: 0.18666666666666668
# trial block: 235 reward: 0.32
# trial block: 236 reward: 0.30666666666666664
# trial block: 237 reward: 0.31666666666666665
# trial block: 238 reward: 0.12666666666666668
# trial block: 239 reward: 0.18666666666666668
# trial block: 240 reward: 0.31
# trial block: 241 reward: 0.31666666666666665
# trial block: 242 reward: 0.2733333333333333
# trial block: 243 reward: 0.33
# trial block: 244 reward: 0.19
# trial block: 245 reward: 0.11
# trial block: 246 reward: 0.11666666666666667
# trial block: 247 reward: 0.28
# trial block: 248 reward: 0.18666666666666668
# trial block: 249 reward: 0.30333333333333334
# trial block: 250 reward: 0.29333333333333333
# trial block: 251 reward: 0.19333333333333333
# trial block: 252 reward: 0.30666666666666664
# trial block: 253 reward: 0.2633333333333333
# trial block: 254 reward: 0.19
# trial block: 255 reward: 0.2733333333333333
# trial block: 256 reward: 0.13
# trial block: 257 reward: 0.19
# trial block: 258 reward: 0.12333333333333334
# trial block: 259 reward: 0.30666666666666664
# trial block: 260 reward: 0.19333333333333333
# trial block: 261 reward: 0.19333333333333333
# trial block: 262 reward: 0.19333333333333333
# trial block: 263 reward: 0.19
# trial block: 264 reward: 0.19333333333333333
# trial block: 265 reward: 0.09666666666666666
# trial block: 266 reward: 0.19666666666666666
# trial block: 267 reward: 0.3
# trial block: 268 reward: 0.2733333333333333
# trial block: 269 reward: 0.19
# trial block: 270 reward: 0.19
# trial block: 271 reward: 0.29333333333333333
# trial block: 272 reward: 0.18666666666666668
# trial block: 273 reward: 0.27
# trial block: 274 reward: 0.30666666666666664
# trial block: 275 reward: 0.31
# trial block: 276 reward: 0.32
# trial block: 277 reward: 0.18666666666666668
# trial block: 278 reward: 0.19333333333333333
# trial block: 279 reward: 0.13
# trial block: 280 reward: 0.12
# trial block: 281 reward: 0.26
# trial block: 282 reward: 0.19
# trial block: 283 reward: 0.3233333333333333
# trial block: 284 reward: 0.29333333333333333
# trial block: 285 reward: 0.32666666666666666
# trial block: 286 reward: 0.11
# trial block: 287 reward: 0.12
# trial block: 288 reward: 0.27666666666666667
# trial block: 289 reward: 0.32
# trial block: 290 reward: 0.12333333333333334
# trial block: 291 reward: 0.12
# trial block: 292 reward: 0.19
# trial block: 293 reward: 0.19
# trial block: 294 reward: 0.11666666666666667
# trial block: 295 reward: 0.31
# trial block: 296 reward: 0.32
# trial block: 297 reward: 0.33
# trial block: 298 reward: 0.29
# trial block: 299 reward: 0.19
# trial block: 300 reward: 0.11666666666666667
# trial block: 301 reward: 0.19333333333333333
# trial block: 302 reward: 0.19333333333333333
# trial block: 303 reward: 0.29
# trial block: 304 reward: 0.3233333333333333
# trial block: 305 reward: 0.2866666666666667
# trial block: 306 reward: 0.31666666666666665
# trial block: 307 reward: 0.27666666666666667
# trial block: 308 reward: 0.27666666666666667
# trial block: 309 reward: 0.19
# trial block: 310 reward: 0.12
# trial block: 311 reward: 0.19
# trial block: 312 reward: 0.32
# trial block: 313 reward: 0.2866666666666667
# trial block: 314 reward: 0.31666666666666665
# trial block: 315 reward: 0.28
# trial block: 316 reward: 0.19
# trial block: 317 reward: 0.31666666666666665
# trial block: 318 reward: 0.18666666666666668
# trial block: 319 reward: 0.19333333333333333
# trial block: 320 reward: 0.18666666666666668
# trial block: 321 reward: 0.29333333333333333
# trial block: 322 reward: 0.19
# trial block: 323 reward: 0.19333333333333333
# trial block: 324 reward: 0.3233333333333333
# trial block: 325 reward: 0.12
# trial block: 326 reward: 0.19
# trial block: 327 reward: 0.27666666666666667
# trial block: 328 reward: 0.32666666666666666
# trial block: 329 reward: 0.30666666666666664
# trial block: 330 reward: 0.32
# trial block: 331 reward: 0.19333333333333333
# trial block: 332 reward: 0.19333333333333333
# trial block: 333 reward: 0.2633333333333333
# trial block: 334 reward: 0.19333333333333333
# trial block: 335 reward: 0.31333333333333335
# trial block: 336 reward: 0.29
# trial block: 337 reward: 0.29333333333333333
# trial block: 338 reward: 0.29333333333333333
# trial block: 339 reward: 0.30333333333333334
# trial block: 340 reward: 0.19
# trial block: 341 reward: 0.3233333333333333
# trial block: 342 reward: 0.19
# trial block: 343 reward: 0.13333333333333333
# trial block: 344 reward: 0.19
# trial block: 345 reward: 0.13
# trial block: 346 reward: 0.12666666666666668
# trial block: 347 reward: 0.32
# trial block: 348 reward: 0.32
# trial block: 349 reward: 0.31
# trial block: 350 reward: 0.31333333333333335
# trial block: 351 reward: 0.11666666666666667
# trial block: 352 reward: 0.19333333333333333
# trial block: 353 reward: 0.30333333333333334
# trial block: 354 reward: 0.30333333333333334
# trial block: 355 reward: 0.19333333333333333
# trial block: 356 reward: 0.27666666666666667
# trial block: 357 reward: 0.29333333333333333
# trial block: 358 reward: 0.2733333333333333
# trial block: 359 reward: 0.12
# trial block: 360 reward: 0.32
# trial block: 361 reward: 0.12333333333333334
# trial block: 362 reward: 0.32
# trial block: 363 reward: 0.32
# trial block: 364 reward: 0.19333333333333333
# trial block: 365 reward: 0.33666666666666667
# trial block: 366 reward: 0.19
# trial block: 367 reward: 0.13
# trial block: 368 reward: 0.19
# trial block: 369 reward: 0.11666666666666667
# trial block: 370 reward: 0.2833333333333333
# trial block: 371 reward: 0.12333333333333334
# trial block: 372 reward: 0.18666666666666668
# trial block: 373 reward: 0.31333333333333335
# trial block: 374 reward: 0.27666666666666667
# trial block: 375 reward: 0.12333333333333334
# trial block: 376 reward: 0.31666666666666665
# trial block: 377 reward: 0.28
# trial block: 378 reward: 0.31333333333333335
# trial block: 379 reward: 0.11333333333333333
# trial block: 380 reward: 0.29
# trial block: 381 reward: 0.19
# trial block: 382 reward: 0.2833333333333333
# trial block: 383 reward: 0.2966666666666667
# trial block: 384 reward: 0.30333333333333334
# trial block: 385 reward: 0.19333333333333333
# trial block: 386 reward: 0.31
# trial block: 387 reward: 0.12
# trial block: 388 reward: 0.30666666666666664
# trial block: 389 reward: 0.19
# trial block: 390 reward: 0.12333333333333334
# trial block: 391 reward: 0.3233333333333333
# trial block: 392 reward: 0.33
# trial block: 393 reward: 0.19
# trial block: 394 reward: 0.29333333333333333
# trial block: 395 reward: 0.11333333333333333
# trial block: 396 reward: 0.10666666666666667
# trial block: 397 reward: 0.19333333333333333
# trial block: 398 reward: 0.3233333333333333
# trial block: 399 reward: 0.30333333333333334
# trial block: 400 reward: 0.11666666666666667
# trial block: 401 reward: 0.29333333333333333
# trial block: 402 reward: 0.12666666666666668
# trial block: 403 reward: 0.3233333333333333
# trial block: 404 reward: 0.12
# trial block: 405 reward: 0.31333333333333335
# trial block: 406 reward: 0.29333333333333333
# trial block: 407 reward: 0.32
# trial block: 408 reward: 0.3233333333333333
# trial block: 409 reward: 0.29333333333333333
# trial block: 410 reward: 0.11666666666666667
# trial block: 411 reward: 0.3
# trial block: 412 reward: 0.19
# trial block: 413 reward: 0.12666666666666668
# trial block: 414 reward: 0.2966666666666667
# trial block: 415 reward: 0.19
# trial block: 416 reward: 0.27666666666666667
# trial block: 417 reward: 0.31333333333333335
# trial block: 418 reward: 0.32666666666666666
# trial block: 419 reward: 0.31666666666666665
# trial block: 420 reward: 0.11666666666666667
# trial block: 421 reward: 0.11666666666666667
# trial block: 422 reward: 0.29333333333333333
# trial block: 423 reward: 0.11666666666666667
# trial block: 424 reward: 0.26
# trial block: 425 reward: 0.32
# trial block: 426 reward: 0.19333333333333333
# trial block: 427 reward: 0.12
# trial block: 428 reward: 0.13333333333333333
# trial block: 429 reward: 0.32
# trial block: 430 reward: 0.19
# trial block: 431 reward: 0.2866666666666667
# trial block: 432 reward: 0.31
# trial block: 433 reward: 0.18666666666666668
# trial block: 434 reward: 0.28
# trial block: 435 reward: 0.19333333333333333
# trial block: 436 reward: 0.12666666666666668
# trial block: 437 reward: 0.19333333333333333
# trial block: 438 reward: 0.30666666666666664
# trial block: 439 reward: 0.11666666666666667
# trial block: 440 reward: 0.2633333333333333
# trial block: 441 reward: 0.18333333333333332
# trial block: 442 reward: 0.28
# trial block: 443 reward: 0.32666666666666666
# trial block: 444 reward: 0.11666666666666667
# trial block: 445 reward: 0.2633333333333333
# trial block: 446 reward: 0.19
# trial block: 447 reward: 0.19
# trial block: 448 reward: 0.19
# trial block: 449 reward: 0.32
# trial block: 450 reward: 0.3233333333333333
# trial block: 451 reward: 0.12333333333333334
# trial block: 452 reward: 0.11666666666666667
# trial block: 453 reward: 0.26
# trial block: 454 reward: 0.27666666666666667
# trial block: 455 reward: 0.32666666666666666
# trial block: 456 reward: 0.31
# trial block: 457 reward: 0.11333333333333333
# trial block: 458 reward: 0.31666666666666665
# trial block: 459 reward: 0.11666666666666667
# trial block: 460 reward: 0.18666666666666668
# trial block: 461 reward: 0.3233333333333333
# trial block: 462 reward: 0.31
# trial block: 463 reward: 0.29333333333333333
# trial block: 464 reward: 0.31333333333333335
# trial block: 465 reward: 0.13
# trial block: 466 reward: 0.31666666666666665
# trial block: 467 reward: 0.33
# trial block: 468 reward: 0.11333333333333333
# trial block: 469 reward: 0.28
# trial block: 470 reward: 0.19333333333333333
# trial block: 471 reward: 0.31333333333333335
# trial block: 472 reward: 0.18666666666666668
# trial block: 473 reward: 0.31333333333333335
# trial block: 474 reward: 0.3333333333333333
# trial block: 475 reward: 0.31333333333333335
# trial block: 476 reward: 0.31333333333333335
# trial block: 477 reward: 0.31666666666666665
# trial block: 478 reward: 0.12333333333333334
# trial block: 479 reward: 0.29333333333333333
# trial block: 480 reward: 0.12666666666666668
# trial block: 481 reward: 0.19333333333333333
# trial block: 482 reward: 0.28
# trial block: 483 reward: 0.31
# trial block: 484 reward: 0.12333333333333334
# trial block: 485 reward: 0.31666666666666665
# trial block: 486 reward: 0.11333333333333333
# trial block: 487 reward: 0.12333333333333334
# trial block: 488 reward: 0.3233333333333333
# trial block: 489 reward: 0.19
# trial block: 490 reward: 0.31666666666666665
# trial block: 491 reward: 0.30666666666666664
# trial block: 492 reward: 0.19
# trial block: 493 reward: 0.32
# trial block: 494 reward: 0.29333333333333333
# trial block: 495 reward: 0.3233333333333333
# trial block: 496 reward: 0.32666666666666666
# trial block: 497 reward: 0.13666666666666666
# trial block: 498 reward: 0.11333333333333333
# trial block: 499 reward: 0.19

# %% [markdown]
# ##  From original paper: "The estimated optimal numbers of trials at the PR side (𝑁_𝑃𝑅∗) are 10, 22, 28, and 58 trials at 2xFR6, 2xFR12, 5xFR6, and 5xFR12 respectively"

# %%
optimal_switch = {(6, 2):10, (12, 2):22, (6, 5):28, (12, 5):58}

# %% [markdown]
# ## From original paper: "The application of this analysis to our dataset revealed that indeed an effect of sunk cost existed. Surprisingly, it is not present in all four conditions of the task. A twoway ANOVA collapsing across sunk cost conditions revealed that the effect was only significant in contexts with a higher cost or benefit parameter"

# %%
for (FR_limit, PR_reward), sessions in d.items():
    example_actions, example_rewards = sessions[np.random.randint(len(sessions))]
    example_actions = 1 - example_actions # to match the original paper's graphs
    plt.figure(figsize = (15, 5))
    scatter = plt.scatter(np.arange(len(example_actions)), example_actions, s = 30, c = example_actions)
    plt.legend(handles=scatter.legend_elements()[0], labels=['FR', 'PR'])
    plt.title('%dxFR%d'%(PR_reward, FR_limit))
    # add optimal line
    switch_time = optimal_switch[(FR_limit, PR_reward)]
    plt.plot([switch_time, switch_time], [0, 1], color='red')
